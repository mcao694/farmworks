# %%
import numpy as np
import pandas as pd
import os

# %%
data_fall23_soup = {
    "Week": [
        "08/28/23", "08/28/23", "08/28/23", "08/28/23", "08/28/23",
        "09/04/23", "09/04/23", "09/04/23", "09/04/23", "09/04/23",
        "09/11/23", "09/11/23", "09/11/23", "09/11/23", "09/11/23",
        "09/18/23", "09/18/23", "09/18/23", "09/18/23", "09/18/23",
        "09/25/23", "09/25/23", "09/25/23", "09/25/23", "09/25/23",
        "10/02/23", "10/02/23", "10/02/23", "10/02/23", "10/02/23",
        "10/09/23", "10/09/23", "10/09/23", "10/09/23", "10/09/23",
        "10/16/23", "10/16/23", "10/16/23",
        "10/23/23", "10/23/23", "10/23/23", "10/23/23", "10/23/23",
        "10/30/23", "10/30/23", "10/30/23", "10/30/23", "10/30/23",
        "11/06/23", "11/06/23", "11/06/23", "11/06/23", "11/06/23",
        "11/13/23", "11/13/23", "11/13/23", "11/13/23", "11/13/23",
        "11/20/23", "11/20/23",
        "11/28/23", "11/28/23", "11/28/23", "11/28/23", "11/28/23",
        "12/04/23", "12/04/23", "12/04/23", "12/04/23", "12/04/23",
        "12/11/23", "12/11/23", "12/11/23", "12/11/23", "12/11/23"
    ],
    "Day": [
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri"
    ],
    "Soup": [
        "Tomato", "Red Lentil", "Sopa de Fideo", "Sweet & Sour Vegetable", "Elote Corn",
        "Moroccan Chickpea & Carrot", "Carrot Ginger", "Cuban Black Bean", "Split Pea", "Red Bean Chili",
        "Tomato", "Cassoulet", "Broccoli Chowder", "Elote Corn", "Red Lentil",
        "Red Bean Chili", "Split Pea", "Sopa de Fideo", "Sweet & Sour Vegetable", "Mulligatawny",
        "Tomato", "Elote Corn", "Cassoulet", "Moroccan Chickpea & Carrot", "Carrot Ginger",
        "New Vegan Clam Chowder", "Split Pea", "Red Bean Chili", "Rustic Potato Curry", "Aloo Palak",
        "Tomato", "Broccoli Chowder", "Cuban Black Bean", "Harira", "Pozole",
        "Cuban Black Bean", "Harira", "Pozole",
        "Tomato", "Split Pea", "Cassoulet", "Rustic Potato Curry", "Red Lentil",
        "Carrot Ginger", "Elote Corn", "Sopa de Fideo", "Red Bean Chili", "New Vegan Clam Chowder",
        "Tomato", "New Vegan Clam Chowder", "Harira", "Aloo Palak", "Rustic Potato Curry",
        "Tomato", "New Vegan Clam Chowder", "Harira", "Aloo Palak", "Rustic Potato Curry",
        "Tomato", "New Vegan Clam Chowder",
        "Tomato", "New Vegan Clam Chowder", "Harira", "Aloo Palak", "Rustic Potato Curry",
        "Tomato", "New Vegan Clam Chowder", "Harira", "Aloo Palak", "Rustic Potato Curry",
        "Tomato", "New Vegan Clam Chowder", "Harira", "Aloo Palak", "Rustic Potato Curry"

    ],
    "Notes": [
        "contains coconut milk", "nf", "nf", "nf", "nf",
        "nf", "contains coconut milk", "nf", "nf", "nf",
        "contains coconut milk", "nf", "nf", "nf", "nf",
        "nf", "nf", "nf", "nf", "nf",
        "contains coconut milk", "nf", "nf", "nf", "contains coconut milk",
        "nf", "nf", "nf", "nf", "contains coconut milk",
        "contains coconut milk", "nf", "nf", "nf", "nf",
        "nf", "nf", "nf",
        "contains coconut milk", "nf", "nf", "nf", "nf",
        "contains coconut milk", "nf", "nf", "nf", "nf",
        "contains coconut milk", "nf", "nf", "nf", "nf",
        "contains coconut milk", "nf", "nf", "nf", "nf",
        "contains coconut milk", "nf",
        "contains coconut milk", "nf", "nf", "contains coconut milk", "nf",
        "contains coconut milk", "nf", "nf", "contains coconut milk", "nf",
        "contains coconut milk", "nf", "nf", "contains coconut milk", "nf"
    ]
}

df_fall23_soup = pd.DataFrame(data_fall23_soup)

df_fall23_soup
# Out:
#         Week   Day                    Soup                  Notes
# 0   08/28/23   Mon                  Tomato  contains coconut milk
# 1   08/28/23  Tues              Red Lentil                     nf
# 2   08/28/23   Wed           Sopa de Fideo                     nf
# 3   08/28/23  Thur  Sweet & Sour Vegetable                     nf
# 4   08/28/23   Fri              Elote Corn                     nf
# ..       ...   ...                     ...                    ...
# 70  12/11/23   Mon                  Tomato  contains coconut milk
# 71  12/11/23  Tues  New Vegan Clam Chowder                     nf
# 72  12/11/23   Wed                  Harira                     nf
# 73  12/11/23  Thur              Aloo Palak  contains coconut milk
# 74  12/11/23   Fri     Rustic Potato Curry                     nf
#
# [75 rows x 4 columns]

# %%
data_fall23_salad = {
    "Week": [
        "08/28/23",
        "09/04/23",
        "09/11/23",
        "09/18/23",
        "09/25/23",
        "10/02/23",
        "10/09/23",
        "10/16/23",
        "10/23/23",
        "10/30/23",
        "11/06/23",
        "11/13/23",
        "11/20/23",
        "11/28/23",
        "12/04/23",
        "12/11/23"
    ],
    "Salad": [
        "Mujadara Bowls w/Parsley-Tahini dressing",
        "Kale Caesar",
        "Middle Eastern Quinoa",
        "Ponzu Noodle",
        "Roasted Fennel & Carrot",
        "Rice Bowl w/Red Kidney Beans, Spinach & mixed veggies",
        "Moroccan Carrot-Beet",
        "Moroccan Carrot-Beet",
        "Kale Caesar",
        "Middle Eastern Quinoa",
        "Moroccan Carrot-Beet",
        "Moroccan Carrot-Beet",
        "Moroccan Carrot-Beet",
        "Moroccan Carrot-Beet",
        "Moroccan Carrot-Beet",
        "Moroccan Carrot-Beet"
    ]
}

df_fall23_salad = pd.DataFrame(data_fall23_salad)

df_fall23_salad
# Out:
#         Week                                              Salad
# 0   08/28/23           Mujadara Bowls w/Parsley-Tahini dressing
# 1   09/04/23                                        Kale Caesar
# 2   09/11/23                              Middle Eastern Quinoa
# 3   09/18/23                                       Ponzu Noodle
# 4   09/25/23                            Roasted Fennel & Carrot
# 5   10/02/23  Rice Bowl w/Red Kidney Beans, Spinach & mixed ...
# 6   10/09/23                               Moroccan Carrot-Beet
# 7   10/16/23                               Moroccan Carrot-Beet
# 8   10/23/23                                        Kale Caesar
# 9   10/30/23                              Middle Eastern Quinoa
# 10  11/06/23                               Moroccan Carrot-Beet
# 11  11/13/23                               Moroccan Carrot-Beet
# 12  11/20/23                               Moroccan Carrot-Beet
# 13  11/28/23                               Moroccan Carrot-Beet
# ...

# %%
# Merge df_fall23_soup and df_fall23_salad
df_fall23_menu = pd.merge(df_fall23_soup, df_fall23_salad, on='Week', how='left')

# Check unique salad counts
salad_counts = df_fall23_menu['Salad'].value_counts()

# Print unique salad counts
print(salad_counts)

df_fall23_menu
# Out:
# Salad
# Moroccan Carrot-Beet                                     35
# Kale Caesar                                              10
# Middle Eastern Quinoa                                    10
# Mujadara Bowls w/Parsley-Tahini dressing                  5
# Ponzu Noodle                                              5
# Roasted Fennel & Carrot                                   5
# Rice Bowl w/Red Kidney Beans, Spinach & mixed veggies     5
# Name: count, dtype: int64
#         Week   Day                    Soup                  Notes  \
# 0   08/28/23   Mon                  Tomato  contains coconut milk
# 1   08/28/23  Tues              Red Lentil                     nf
# 2   08/28/23   Wed           Sopa de Fideo                     nf
# 3   08/28/23  Thur  Sweet & Sour Vegetable                     nf
# 4   08/28/23   Fri              Elote Corn                     nf
# ..       ...   ...                     ...                    ...
# ...

# %%
# Convert 'Week' to datetime
df_fall23_menu['Week'] = pd.to_datetime(df_fall23_menu['Week'], format='%m/%d/%y')

# Increment days based on the 'Day' column
df_fall23_menu['Week'] = df_fall23_menu.apply(
    lambda row: row['Week'] + pd.Timedelta(days={"Mon": 0, "Tues": 1, "Wed": 2, "Thur": 3, "Fri": 4}[row['Day']]),
    axis=1
)

df_fall23_menu
# Out:
#          Week   Day                    Soup                  Notes  \
# 0  2023-08-28   Mon                  Tomato  contains coconut milk
# 1  2023-08-29  Tues              Red Lentil                     nf
# 2  2023-08-30   Wed           Sopa de Fideo                     nf
# 3  2023-08-31  Thur  Sweet & Sour Vegetable                     nf
# 4  2023-09-01   Fri              Elote Corn                     nf
# ..        ...   ...                     ...                    ...
# 70 2023-12-11   Mon                  Tomato  contains coconut milk
# 71 2023-12-12  Tues  New Vegan Clam Chowder                     nf
# 72 2023-12-13   Wed                  Harira                     nf
# 73 2023-12-14  Thur              Aloo Palak  contains coconut milk
# 74 2023-12-15   Fri     Rustic Potato Curry                     nf
#
#                                        Salad
# 0   Mujadara Bowls w/Parsley-Tahini dressing
# 1   Mujadara Bowls w/Parsley-Tahini dressing
# ...

# %%
data_fall23_emp = {
    "Week": [
        "08/28/23",
        "09/04/23",
        "09/11/23",
        "09/18/23",
        "09/25/23",
        "10/02/23",
        "10/09/23",
        "10/16/23",
        "10/23/23",
        "10/30/23",
        "11/06/23",
        "11/13/23",
        "11/20/23",
        "11/28/23",
        "12/04/23",
        "12/11/23"
    ],
    "Empanada": [
        "Creole",
        "Three Sisters",
        "Veg Chimichurri",
        "Creole",
        "Three Sisters",
        "Veg Chimichurri",
        "Creole",
        "Three Sisters",
        "Veg Chimichurri",
        "Rustic Potato Curry",
        "Three Sisters",
        "Three Sisters",
        "",
        "Three Sisters",
        "Three Sisters",
        "Three Sisters"
    ]
}

df_fall23_emp = pd.DataFrame(data_fall23_emp)

df_fall23_emp
# Out:
#         Week             Empanada
# 0   08/28/23               Creole
# 1   09/04/23        Three Sisters
# 2   09/11/23      Veg Chimichurri
# 3   09/18/23               Creole
# 4   09/25/23        Three Sisters
# 5   10/02/23      Veg Chimichurri
# 6   10/09/23               Creole
# 7   10/16/23        Three Sisters
# 8   10/23/23      Veg Chimichurri
# 9   10/30/23  Rustic Potato Curry
# 10  11/06/23        Three Sisters
# 11  11/13/23        Three Sisters
# 12  11/20/23
# 13  11/28/23        Three Sisters
# 14  12/04/23        Three Sisters
# 15  12/11/23        Three Sisters

# %%
# Convert the 'Week' column to datetime
df_fall23_emp['Week'] = pd.to_datetime(df_fall23_emp['Week'], format='%m/%d/%y')

# Shift the 'Week' column by 2 days
df_fall23_emp['Week'] = df_fall23_emp['Week'] + pd.Timedelta(days=2)

df_fall23_emp
# Out:
#          Week             Empanada
# 0  2023-08-30               Creole
# 1  2023-09-06        Three Sisters
# 2  2023-09-13      Veg Chimichurri
# 3  2023-09-20               Creole
# 4  2023-09-27        Three Sisters
# 5  2023-10-04      Veg Chimichurri
# 6  2023-10-11               Creole
# 7  2023-10-18        Three Sisters
# 8  2023-10-25      Veg Chimichurri
# 9  2023-11-01  Rustic Potato Curry
# 10 2023-11-08        Three Sisters
# 11 2023-11-15        Three Sisters
# 12 2023-11-22
# 13 2023-11-30        Three Sisters
# 14 2023-12-06        Three Sisters
# 15 2023-12-13        Three Sisters

# %%
# Merge df_fall23_menu and df_fall23_emp
df_fall23_menu = pd.merge(df_fall23_menu, df_fall23_emp, on='Week', how='left')

df_fall23_menu
# Out:
#          Week   Day                    Soup                  Notes  \
# 0  2023-08-28   Mon                  Tomato  contains coconut milk
# 1  2023-08-29  Tues              Red Lentil                     nf
# 2  2023-08-30   Wed           Sopa de Fideo                     nf
# 3  2023-08-31  Thur  Sweet & Sour Vegetable                     nf
# 4  2023-09-01   Fri              Elote Corn                     nf
# ..        ...   ...                     ...                    ...
# 70 2023-12-11   Mon                  Tomato  contains coconut milk
# 71 2023-12-12  Tues  New Vegan Clam Chowder                     nf
# 72 2023-12-13   Wed                  Harira                     nf
# 73 2023-12-14  Thur              Aloo Palak  contains coconut milk
# 74 2023-12-15   Fri     Rustic Potato Curry                     nf
#
#                                        Salad       Empanada
# 0   Mujadara Bowls w/Parsley-Tahini dressing            NaN
# ...

# %%
# Creating a DataFrame based on the Spring24 menu file data
data_spring24_soup = {
    "Week": [
        "01/22/24", "01/22/24", "01/22/24", "01/22/24", "01/22/24",
        "01/29/24", "01/29/24", "01/29/24", "01/29/24", "01/29/24",
        "02/05/24", "02/05/24", "02/05/24", "02/05/24", "02/05/24",
        "02/12/24", "02/12/24", "02/12/24", "02/12/24", "02/12/24",
        "02/19/24", "02/19/24", "02/19/24", "02/19/24", "02/19/24",
        "02/26/24", "02/26/24", "02/26/24", "02/26/24", "02/26/24",
        "03/04/24", "03/04/24", "03/04/24", "03/04/24", "03/04/24",
        "03/18/24", "03/18/24", "03/18/24", "03/18/24", "03/18/24",
        "03/25/24", "03/25/24", "03/25/24", "03/25/24", "03/25/24",
        "04/01/24", "04/01/24", "04/01/24", "04/01/24", "04/01/24",
        "04/08/24", "04/08/24", "04/08/24", "04/08/24", "04/08/24",
        "04/15/24", "04/15/24", "04/15/24", "04/15/24", "04/15/24",
        "04/22/24", "04/22/24", "04/22/24", "04/22/24", "04/22/24",
        "04/29/24", "04/29/24", "04/29/24", "04/29/24", "04/29/24",
        "05/06/24", "05/06/24", "05/06/24", "05/06/24", "05/06/24"
    ],
    "Day": [
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri"
    ],
    "Soup": [
        "Sweet Potato Bisque", "Creamy Cauliflower", "Tomato", "Rustic Potato Curry", "Red Bean Chili",
        "Split Pea", "Moroccan Chickpea & Carrot", "Cuban Black Bean", "Red Lentil", "Roasted Cauliflower & Sweet Potato",
        "Tomato", "Potato Leek", "Pasta Fagioli", "Carrot Ginger", "Butternut Squash Moroccan Chili",
        "Creamy Cauliflower", "Potato & Kale Minestrone", "Sweet Potato Bisque", "Rustic Potato Curry", "Cassoulet",
        "Tomato", "Moroccan Chickpea & Carrot", "Cuban Black Bean", "Potato Leek", "Tom Yum",
        "Split Pea", "Red Lentil", "Pasta Fagioli", "Rustic Potato Curry", "Pozole",
        "Creamy Cauliflower", "Potato Leek", "Tomato", "Red Bean Chili", "Vegan Chicken Noodle",
        "Sweet Potato Bisque", "Cassoulet", "Red Lentil", "Butternut Squash Moroccan Chili", "Carrot Ginger",
        "Tomato", "Creamy Cauliflower", "Cuban Black Bean", "Rustic Potato Curry", "Pozole",
        "Split Pea", "Potato Leek", "Pasta Fagioli", "Moroccan Chickpea & Carrot", "Red Bean Chili",
        "Tomato", "Carrot Ginger", "Cuban Black Bean", "Red Lentil", "Butternut Squash Moroccan Chili",
        "Creamy Cauliflower", "Split Pea", "Cassoulet", "Rustic Potato Curry", "Tom Yum",
        "Red Lentil", "Carrot Ginger", "Cuban Black Bean", "Red Bean Chili", "Vegan Chicken Noodle",
        "Sweet Potato Bisque", "Tomato", "Elote", "Roasted Cauliflower & Sweet Potato", "Pozole",
        "Tomato", "Split Pea", "Fideo", "Rustic Potato Curry", "Carrot Ginger"
    ]
}

df_spring24_soup = pd.DataFrame(data_spring24_soup)

# Displaying the Spring 2024 menu DataFrame
df_spring24_soup
# Out:
#         Week   Day                 Soup
# 0   01/22/24   Mon  Sweet Potato Bisque
# 1   01/22/24  Tues   Creamy Cauliflower
# 2   01/22/24   Wed               Tomato
# 3   01/22/24  Thur  Rustic Potato Curry
# 4   01/22/24   Fri       Red Bean Chili
# ..       ...   ...                  ...
# 70  05/06/24   Mon               Tomato
# 71  05/06/24  Tues            Split Pea
# 72  05/06/24   Wed                Fideo
# 73  05/06/24  Thur  Rustic Potato Curry
# 74  05/06/24   Fri        Carrot Ginger
#
# [75 rows x 3 columns]

# %%
# Creating a DataFrame based on the Spring24 menu file data
data_spring24_salad = {
    "Week": [
        "01/22/24",
        "01/29/24",
        "02/05/24",
        "02/12/24",
        "02/19/24",
        "02/26/24",
        "03/04/24",
        "03/18/24",
        "03/25/24",
        "04/01/24",
        "04/08/24",
        "04/15/24",
        "04/22/24",
        "04/29/24",
        "05/06/24"
    ],
    "Salad": [
        "Roasted Cabbage Wedges w/Creamy Lemon Dressing",
        "Kale w/Roasted Chickpeas & Beets",
        "Kale Caesar",
        "Potato Salad",
        "Roasted Butternut Squash w/Millet",
        "Black Bean Quinoa",
        "Thai Cabbage w/Rice & Sweet Potatoes",
        "Rice Noodle Pasta Salad",
        "Kale w/Roasted Butternut Squash & Lentils",
        "Moroccan Carrot & Beet",
        "Thai Cabbage w/Rice & Sweet Potatoes",
        "Ponzu Noodle",
        "Coleslaw w/BBQ Chickpeas",
        "Kale Caesar",
        ""
    ]
}

df_spring24_salad = pd.DataFrame(data_spring24_salad)

# Displaying the Spring 2024 menu DataFrame
df_spring24_salad
# Out:
#         Week                                           Salad
# 0   01/22/24  Roasted Cabbage Wedges w/Creamy Lemon Dressing
# 1   01/29/24                Kale w/Roasted Chickpeas & Beets
# 2   02/05/24                                     Kale Caesar
# 3   02/12/24                                    Potato Salad
# 4   02/19/24               Roasted Butternut Squash w/Millet
# 5   02/26/24                               Black Bean Quinoa
# 6   03/04/24            Thai Cabbage w/Rice & Sweet Potatoes
# 7   03/18/24                         Rice Noodle Pasta Salad
# 8   03/25/24       Kale w/Roasted Butternut Squash & Lentils
# 9   04/01/24                          Moroccan Carrot & Beet
# 10  04/08/24            Thai Cabbage w/Rice & Sweet Potatoes
# 11  04/15/24                                    Ponzu Noodle
# 12  04/22/24                        Coleslaw w/BBQ Chickpeas
# 13  04/29/24                                     Kale Caesar
# 14  05/06/24

# %%
# Merge df_spring24_soup and df_spring24_salad
df_spring24_menu = pd.merge(df_spring24_soup, df_spring24_salad, on='Week', how='left')

# Check unique salad counts
salad_counts = df_spring24_menu['Salad'].value_counts()

# Print unique salad counts
print(salad_counts)

df_spring24_menu
# Out:
# Salad
# Kale Caesar                                       10
# Thai Cabbage w/Rice & Sweet Potatoes              10
# Roasted Cabbage Wedges w/Creamy Lemon Dressing     5
# Kale w/Roasted Chickpeas & Beets                   5
# Potato Salad                                       5
# Roasted Butternut Squash w/Millet                  5
# Black Bean Quinoa                                  5
# Rice Noodle Pasta Salad                            5
# Kale w/Roasted Butternut Squash & Lentils          5
# Moroccan Carrot & Beet                             5
# Ponzu Noodle                                       5
# Coleslaw w/BBQ Chickpeas                           5
#                                                    5
# Name: count, dtype: int64
#         Week   Day                 Soup  \
# 0   01/22/24   Mon  Sweet Potato Bisque
# 1   01/22/24  Tues   Creamy Cauliflower
# 2   01/22/24   Wed               Tomato
# 3   01/22/24  Thur  Rustic Potato Curry
# ...

# %%
# Convert 'Week' to datetime
df_spring24_menu['Week'] = pd.to_datetime(df_spring24_menu['Week'], format='%m/%d/%y')

# Increment days based on the 'Day' column
df_spring24_menu['Week'] = df_spring24_menu.apply(
    lambda row: row['Week'] + pd.Timedelta(days={"Mon": 0, "Tues": 1, "Wed": 2, "Thur": 3, "Fri": 4}[row['Day']]),
    axis=1
)

df_spring24_menu
# Out:
#          Week   Day                 Soup  \
# 0  2024-01-22   Mon  Sweet Potato Bisque
# 1  2024-01-23  Tues   Creamy Cauliflower
# 2  2024-01-24   Wed               Tomato
# 3  2024-01-25  Thur  Rustic Potato Curry
# 4  2024-01-26   Fri       Red Bean Chili
# ..        ...   ...                  ...
# 70 2024-05-06   Mon               Tomato
# 71 2024-05-07  Tues            Split Pea
# 72 2024-05-08   Wed                Fideo
# 73 2024-05-09  Thur  Rustic Potato Curry
# 74 2024-05-10   Fri        Carrot Ginger
#
#                                              Salad
# 0   Roasted Cabbage Wedges w/Creamy Lemon Dressing
# 1   Roasted Cabbage Wedges w/Creamy Lemon Dressing
# 2   Roasted Cabbage Wedges w/Creamy Lemon Dressing
# 3   Roasted Cabbage Wedges w/Creamy Lemon Dressing
# 4   Roasted Cabbage Wedges w/Creamy Lemon Dressing
# ..                                             ...
# 70
# 71
# 72
# 73
# 74
#
# [75 rows x 4 columns]

# %%
# Creating a DataFrame based on the Spring24 menu file data
data_spring24_emp = {
    "Week": [
        "01/22/24",
        "01/29/24",
        "02/05/24",
        "02/12/24",
        "02/19/24",
        "02/26/24",
        "03/04/24",
        "03/18/24",
        "03/25/24",
        "04/01/24",
        "04/08/24",
        "04/15/24",
        "04/22/24",
        "04/29/24",
        "05/06/24"
    ],
    "Empanada": [
        "Three Sisters",
        "Veg Chimichurri",
        "Colorado Red Chile",
        "Creole",
        "Rustic Potato Curry",
        "Sweet Potato & Lentil",
        "Colorado Red Chile",
        "Veg Chimichurri",
        "Rustic Potato Curry",
        "Sweet Potato & Lentil",
        "Veg Chimichurri",
        "Colorado Red Chile",
        "Rustic Potato Curry",
        "Sweet Potato & Lentil",
        "Veg Chimichurri"
    ]
}

df_spring24_emp = pd.DataFrame(data_spring24_emp)

# Displaying the Spring 2024 menu DataFrame
df_spring24_emp
# Out:
#         Week               Empanada
# 0   01/22/24          Three Sisters
# 1   01/29/24        Veg Chimichurri
# 2   02/05/24     Colorado Red Chile
# 3   02/12/24                 Creole
# 4   02/19/24    Rustic Potato Curry
# 5   02/26/24  Sweet Potato & Lentil
# 6   03/04/24     Colorado Red Chile
# 7   03/18/24        Veg Chimichurri
# 8   03/25/24    Rustic Potato Curry
# 9   04/01/24  Sweet Potato & Lentil
# 10  04/08/24        Veg Chimichurri
# 11  04/15/24     Colorado Red Chile
# 12  04/22/24    Rustic Potato Curry
# 13  04/29/24  Sweet Potato & Lentil
# 14  05/06/24        Veg Chimichurri

# %%
# Convert the 'Week' column to datetime
df_spring24_emp['Week'] = pd.to_datetime(df_spring24_emp['Week'], format='%m/%d/%y')

# Shift the 'Week' column by 2 days
df_spring24_emp['Week'] = df_spring24_emp['Week'] + pd.Timedelta(days=2)

df_spring24_emp
# Out:
#          Week               Empanada
# 0  2024-01-24          Three Sisters
# 1  2024-01-31        Veg Chimichurri
# 2  2024-02-07     Colorado Red Chile
# 3  2024-02-14                 Creole
# 4  2024-02-21    Rustic Potato Curry
# 5  2024-02-28  Sweet Potato & Lentil
# 6  2024-03-06     Colorado Red Chile
# 7  2024-03-20        Veg Chimichurri
# 8  2024-03-27    Rustic Potato Curry
# 9  2024-04-03  Sweet Potato & Lentil
# 10 2024-04-10        Veg Chimichurri
# 11 2024-04-17     Colorado Red Chile
# 12 2024-04-24    Rustic Potato Curry
# 13 2024-05-01  Sweet Potato & Lentil
# 14 2024-05-08        Veg Chimichurri

# %%
# Merge df_spring24_menu and df_spring24_emp
df_spring24_menu = pd.merge(df_spring24_menu, df_spring24_emp, on='Week', how='left')

df_spring24_menu
# Out:
#          Week   Day                 Soup  \
# 0  2024-01-22   Mon  Sweet Potato Bisque
# 1  2024-01-23  Tues   Creamy Cauliflower
# 2  2024-01-24   Wed               Tomato
# 3  2024-01-25  Thur  Rustic Potato Curry
# 4  2024-01-26   Fri       Red Bean Chili
# ..        ...   ...                  ...
# 70 2024-05-06   Mon               Tomato
# 71 2024-05-07  Tues            Split Pea
# 72 2024-05-08   Wed                Fideo
# 73 2024-05-09  Thur  Rustic Potato Curry
# 74 2024-05-10   Fri        Carrot Ginger
#
#                                              Salad         Empanada
# 0   Roasted Cabbage Wedges w/Creamy Lemon Dressing              NaN
# 1   Roasted Cabbage Wedges w/Creamy Lemon Dressing              NaN
# 2   Roasted Cabbage Wedges w/Creamy Lemon Dressing    Three Sisters
# 3   Roasted Cabbage Wedges w/Creamy Lemon Dressing              NaN
# 4   Roasted Cabbage Wedges w/Creamy Lemon Dressing              NaN
# ...

# %%
# Merge df_fall23_menu and df_spring24_menu by rows
df_menu = pd.concat([df_fall23_menu, df_spring24_menu], axis=0)

print(df_menu.head(10))
print(df_menu.tail(10))
# Out:
#         Week   Day                        Soup                  Notes  \
# 0 2023-08-28   Mon                      Tomato  contains coconut milk
# 1 2023-08-29  Tues                  Red Lentil                     nf
# 2 2023-08-30   Wed               Sopa de Fideo                     nf
# 3 2023-08-31  Thur      Sweet & Sour Vegetable                     nf
# 4 2023-09-01   Fri                  Elote Corn                     nf
# 5 2023-09-04   Mon  Moroccan Chickpea & Carrot                     nf
# 6 2023-09-05  Tues               Carrot Ginger  contains coconut milk
# 7 2023-09-06   Wed            Cuban Black Bean                     nf
# 8 2023-09-07  Thur                   Split Pea                     nf
# 9 2023-09-08   Fri              Red Bean Chili                     nf
#
#                                       Salad       Empanada
# 0  Mujadara Bowls w/Parsley-Tahini dressing            NaN
# 1  Mujadara Bowls w/Parsley-Tahini dressing            NaN
# ...

# %%
# print(df_menu.Soup.value_counts())
# print(df_menu.Salad.value_counts())
# print(df_menu.Empanada.value_counts())

# %%
# Structured data extracted from the file
data_fall24_soup = {
    "Week": [
        "09/02/24", "09/02/24", "09/02/24", "09/02/24", "09/02/24",
        "09/09/24", "09/09/24", "09/09/24", "09/09/24", "09/09/24",
        "09/16/24", "09/16/24", "09/16/24", "09/16/24", "09/16/24",
        "09/23/24", "09/23/24", "09/23/24", "09/23/24", "09/23/24",
        "09/30/24", "09/30/24", "09/30/24", "09/30/24", "09/30/24",
        "10/07/24", "10/07/24", "10/07/24", "10/07/24", "10/07/24",
        "10/14/24", "10/14/24", "10/14/24", "10/14/24", "10/14/24",
        "10/23/24", "10/23/24", "10/23/24",
        "10/28/24", "10/28/24", "10/28/24", "10/28/24", "10/28/24",
        "11/04/24", "11/04/24", "11/04/24", "11/04/24", "11/04/24",
        "11/11/24", "11/11/24", "11/11/24", "11/11/24", "11/11/24",
        "11/18/24", "11/18/24", "11/18/24", "11/18/24", "11/18/24",
        "11/25/24", "11/25/24",
        "12/02/24", "12/02/24", "12/02/24", "12/02/24", "12/02/24",
        "12/09/24", "12/09/24", "12/09/24", "12/09/24", "12/09/24"
    ],
    "Day": [
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues",
        "Mon", "Tues", "Wed", "Thur", "Fri",
        "Mon", "Tues", "Wed", "Thur", "Fri"
    ],
    "Soup": [
        "Tomato", "Moroccan Chickpea & Carrot", "Cuban Black Bean", "Rustic Potato Curry", "Red Bean Chili",
        "Split Pea", "Carrot Ginger", "Red Lentil", "Pasta Fagioli", "Harira",
        "Tomato", "Potato Leek", "Cuban Black Bean", "Sopa de Fideo", "Butternut Squash Moroccan Chili",
        "Creamy Cauliflower", "Cassoulet", "Sweet Potato Bisque", "Rustic Potato Curry", "Potato & Kale Minestrone",
        "Tomato", "Elote Corn", "Cuban Black Bean", "Red Lentil", "Pozole",
        "Split Pea", "Carrot Ginger", "Moroccan Chickpea & Carrot", "Pasta Fagioli", "Aloo Palak",
        "Red Bean Chili", "Tomato", "Minestrone", "Elote Corn", "Vegan Chicken Noodle",
        "Red Lentil", "Butternut Squash Moroccan Chili", "Tom Yum",
        "Tomato", "Cuban Black Bean", "Cassoulet", "Rustic Potato Curry", "Pozole",
        "Split Pea", "Pasta Fagioli", "Potato Leek", "Moroccan Chickpea & Carrot", "Red Bean Chili",
        "Tomato", "Cuban Black Bean", "Carrot Ginger", "Red Lentil", "Butternut Squash Moroccan Chili",
        "Creamy Cauliflower", "Cassoulet", "Split Pea", "Rustic Potato Curry", "Mulligatawny",
        "Cuban Black Bean", "Red Lentil",
        "Sweet Potato Bisque", "Tomato", "Roasted Cauliflower & Sweet Potato", "Moroccan Chickpea & Carrot", "Pozole",
        "Tomato", "Split Pea", "Fideo", "Rustic Potato Curry", "Carrot Ginger"
    ]
}

# Create the DataFrame
df_fall24_soup = pd.DataFrame(data_fall24_soup)

# Display the DataFrame
df_fall24_soup
# Out:
#         Week   Day                        Soup
# 0   09/02/24   Mon                      Tomato
# 1   09/02/24  Tues  Moroccan Chickpea & Carrot
# 2   09/02/24   Wed            Cuban Black Bean
# 3   09/02/24  Thur         Rustic Potato Curry
# 4   09/02/24   Fri              Red Bean Chili
# ..       ...   ...                         ...
# 65  12/09/24   Mon                      Tomato
# 66  12/09/24  Tues                   Split Pea
# 67  12/09/24   Wed                       Fideo
# 68  12/09/24  Thur         Rustic Potato Curry
# 69  12/09/24   Fri               Carrot Ginger
#
# [70 rows x 3 columns]

# %%
# Structured data extracted from the file
data_fall24_salad = {
    "Week": [
        "09/02/24",
        "09/09/24",
        "09/16/24",
        "09/23/24",
        "09/30/24",
        "10/07/24",
        "10/14/24",
        "10/23/24",
        "10/28/24",
        "11/04/24",
        "11/11/24",
        "11/18/24",
        "11/25/24",
        "12/02/24",
        "12/09/24"
    ],
    "Salad": [
        "Cilantro Ranch Bean Salad",
        "Middle Eastern Quinoa Salad",
        "Kale Caesar",
        "Potato Salad",
        "Roasted Butternut Squash w/Millet",
        "Wild Rice Salad w/Roasted Sweet Potatoes",
        "Pasta Salad w/Rice Noodles",
        "Thai Cabbage w/Rice & Sweet Potatoes",
        "Kale w/Roasted Butternut Squash & Lentils",
        "Moroccan Carrot & Beet",
        "Kale Caesar",
        "Spinach & Lentil Salad w/Potatoes	",
        "Coleslaw",
        "Cilantro Ranch Bean Salad",
        ""
    ]
}

# Create the DataFrame
df_fall24_salad = pd.DataFrame(data_fall24_salad)

# Display the DataFrame
df_fall24_salad
# Out:
#         Week                                      Salad
# 0   09/02/24                  Cilantro Ranch Bean Salad
# 1   09/09/24                Middle Eastern Quinoa Salad
# 2   09/16/24                                Kale Caesar
# 3   09/23/24                               Potato Salad
# 4   09/30/24          Roasted Butternut Squash w/Millet
# 5   10/07/24   Wild Rice Salad w/Roasted Sweet Potatoes
# 6   10/14/24                 Pasta Salad w/Rice Noodles
# 7   10/23/24       Thai Cabbage w/Rice & Sweet Potatoes
# 8   10/28/24  Kale w/Roasted Butternut Squash & Lentils
# 9   11/04/24                     Moroccan Carrot & Beet
# 10  11/11/24                                Kale Caesar
# 11  11/18/24        Spinach & Lentil Salad w/Potatoes\t
# 12  11/25/24                                   Coleslaw
# 13  12/02/24                  Cilantro Ranch Bean Salad
# 14  12/09/24

# %%
# Merge df_fall23_soup and df_fall23_salad
df_fall24_menu = pd.merge(df_fall24_soup, df_fall24_salad, on='Week', how='left')

# Check unique salad counts
salad_counts = df_fall24_menu['Salad'].value_counts()

# Print unique salad counts
print(salad_counts)

df_fall24_menu
# Out:
# Salad
# Cilantro Ranch Bean Salad                    10
# Kale Caesar                                  10
# Middle Eastern Quinoa Salad                   5
# Potato Salad                                  5
# Roasted Butternut Squash w/Millet             5
# Wild Rice Salad w/Roasted Sweet Potatoes      5
# Pasta Salad w/Rice Noodles                    5
# Kale w/Roasted Butternut Squash & Lentils     5
# Moroccan Carrot & Beet                        5
# Spinach & Lentil Salad w/Potatoes\t           5
#                                               5
# Thai Cabbage w/Rice & Sweet Potatoes          3
# Coleslaw                                      2
# Name: count, dtype: int64
#         Week   Day                        Soup                      Salad
# 0   09/02/24   Mon                      Tomato  Cilantro Ranch Bean Salad
# 1   09/02/24  Tues  Moroccan Chickpea & Carrot  Cilantro Ranch Bean Salad
# 2   09/02/24   Wed            Cuban Black Bean  Cilantro Ranch Bean Salad
# ...

# %%
# Convert 'Week' to datetime
df_fall24_menu['Week'] = pd.to_datetime(df_fall24_menu['Week'], format='%m/%d/%y')

# Increment days based on the 'Day' column
df_fall24_menu['Week'] = df_fall24_menu.apply(
    lambda row: row['Week'] + pd.Timedelta(days={"Mon": 0, "Tues": 1, "Wed": 2, "Thur": 3, "Fri": 4}[row['Day']]),
    axis=1
)

df_fall24_menu
# Out:
#          Week   Day                        Soup                      Salad
# 0  2024-09-02   Mon                      Tomato  Cilantro Ranch Bean Salad
# 1  2024-09-03  Tues  Moroccan Chickpea & Carrot  Cilantro Ranch Bean Salad
# 2  2024-09-04   Wed            Cuban Black Bean  Cilantro Ranch Bean Salad
# 3  2024-09-05  Thur         Rustic Potato Curry  Cilantro Ranch Bean Salad
# 4  2024-09-06   Fri              Red Bean Chili  Cilantro Ranch Bean Salad
# ..        ...   ...                         ...                        ...
# 65 2024-12-09   Mon                      Tomato
# 66 2024-12-10  Tues                   Split Pea
# 67 2024-12-11   Wed                       Fideo
# 68 2024-12-12  Thur         Rustic Potato Curry
# 69 2024-12-13   Fri               Carrot Ginger
#
# [70 rows x 4 columns]

# %%
# Structured data extracted from the file
data_fall24_emp = {
    "Week": [
        "09/02/24",
        "09/09/24",
        "09/16/24",
        "09/23/24",
        "09/30/24",
        "10/07/24",
        "10/14/24",
        "10/23/24",
        "10/28/24",
        "11/04/24",
        "11/11/24",
        "11/18/24",
        "11/25/24",
        "12/02/24",
        "12/09/24"
    ],
    "Empanada": [
        "Three Sisters",
        "Veg Chimichurri",
        "Sweet Potato & Lentil",
        "Creole",
        "Veg Chimichurri",
        "Sweet Potato & Lentil",
        "Three Sisters",
        "Creole",
        "Veg Chimichurri",
        "Three Sisters",
        "Veg Chimichurri",
        "Three Sisters",
        "Creole",
        "Sweet Potato & Lentil",
        ""
    ]
}

# Create the DataFrame
df_fall24_emp = pd.DataFrame(data_fall24_emp)

# Display the DataFrame
df_fall24_emp
# Out:
#         Week               Empanada
# 0   09/02/24          Three Sisters
# 1   09/09/24        Veg Chimichurri
# 2   09/16/24  Sweet Potato & Lentil
# 3   09/23/24                 Creole
# 4   09/30/24        Veg Chimichurri
# 5   10/07/24  Sweet Potato & Lentil
# 6   10/14/24          Three Sisters
# 7   10/23/24                 Creole
# 8   10/28/24        Veg Chimichurri
# 9   11/04/24          Three Sisters
# 10  11/11/24        Veg Chimichurri
# 11  11/18/24          Three Sisters
# 12  11/25/24                 Creole
# 13  12/02/24  Sweet Potato & Lentil
# 14  12/09/24

# %%
# Convert the 'Week' column to datetime
df_fall24_emp['Week'] = pd.to_datetime(df_fall24_emp['Week'], format='%m/%d/%y')

# Shift the 'Week' column by 1 days
df_fall24_emp['Week'] = df_fall24_emp['Week'] + pd.Timedelta(days=1)

# Create a shifted DataFrame by 2 days
df_shifted = df_fall24_emp.copy()
df_shifted['Week'] = df_shifted['Week'] + pd.Timedelta(days=2)

# Combine original and shifted DataFrame
df_fall24_emp = pd.concat([df_fall24_emp, df_shifted]).sort_values('Week').reset_index(drop=True)

df_fall24_emp
# Out:
#          Week               Empanada
# 0  2024-09-03          Three Sisters
# 1  2024-09-05          Three Sisters
# 2  2024-09-10        Veg Chimichurri
# 3  2024-09-12        Veg Chimichurri
# 4  2024-09-17  Sweet Potato & Lentil
# 5  2024-09-19  Sweet Potato & Lentil
# 6  2024-09-24                 Creole
# 7  2024-09-26                 Creole
# 8  2024-10-01        Veg Chimichurri
# 9  2024-10-03        Veg Chimichurri
# 10 2024-10-08  Sweet Potato & Lentil
# 11 2024-10-10  Sweet Potato & Lentil
# 12 2024-10-15          Three Sisters
# 13 2024-10-17          Three Sisters
# 14 2024-10-24                 Creole
# 15 2024-10-26                 Creole
# 16 2024-10-29        Veg Chimichurri
# 17 2024-10-31        Veg Chimichurri
# 18 2024-11-05          Three Sisters
# 19 2024-11-07          Three Sisters
# 20 2024-11-12        Veg Chimichurri
# 21 2024-11-14        Veg Chimichurri
# 22 2024-11-19          Three Sisters
# 23 2024-11-21          Three Sisters
# ...

# %%
# Merge df_spring24_menu and df_spring24_emp
df_fall24_menu = pd.merge(df_fall24_menu, df_fall24_emp, on='Week', how='left')

df_fall24_menu
# Out:
#          Week   Day                        Soup                      Salad  \
# 0  2024-09-02   Mon                      Tomato  Cilantro Ranch Bean Salad
# 1  2024-09-03  Tues  Moroccan Chickpea & Carrot  Cilantro Ranch Bean Salad
# 2  2024-09-04   Wed            Cuban Black Bean  Cilantro Ranch Bean Salad
# 3  2024-09-05  Thur         Rustic Potato Curry  Cilantro Ranch Bean Salad
# 4  2024-09-06   Fri              Red Bean Chili  Cilantro Ranch Bean Salad
# ..        ...   ...                         ...                        ...
# 65 2024-12-09   Mon                      Tomato
# 66 2024-12-10  Tues                   Split Pea
# 67 2024-12-11   Wed                       Fideo
# 68 2024-12-12  Thur         Rustic Potato Curry
# 69 2024-12-13   Fri               Carrot Ginger
#
#          Empanada
# 0             NaN
# 1   Three Sisters
# 2             NaN
# 3   Three Sisters
# 4             NaN
# ..            ...
# 65            NaN
# 66
# 67            NaN
# 68
# ...

# %%
# Merge df_fall23_menu and df_spring24_menu by rows
df_menu = pd.concat([df_menu, df_fall24_menu], axis=0)

print(df_menu.head(10))
print(df_menu.tail(10))
# Out:
#         Week   Day                        Soup                  Notes  \
# 0 2023-08-28   Mon                      Tomato  contains coconut milk
# 1 2023-08-29  Tues                  Red Lentil                     nf
# 2 2023-08-30   Wed               Sopa de Fideo                     nf
# 3 2023-08-31  Thur      Sweet & Sour Vegetable                     nf
# 4 2023-09-01   Fri                  Elote Corn                     nf
# 5 2023-09-04   Mon  Moroccan Chickpea & Carrot                     nf
# 6 2023-09-05  Tues               Carrot Ginger  contains coconut milk
# 7 2023-09-06   Wed            Cuban Black Bean                     nf
# 8 2023-09-07  Thur                   Split Pea                     nf
# 9 2023-09-08   Fri              Red Bean Chili                     nf
#
#                                       Salad       Empanada
# 0  Mujadara Bowls w/Parsley-Tahini dressing            NaN
# 1  Mujadara Bowls w/Parsley-Tahini dressing            NaN
# ...

# %%
print(df_menu.Soup.value_counts())
print(df_menu.Salad.value_counts())
print(df_menu.Empanada.value_counts())
# Out:
# Soup
# Tomato                                27
# Rustic Potato Curry                   18
# Cuban Black Bean                      14
# Split Pea                             14
# Red Lentil                            13
# Carrot Ginger                         12
# Red Bean Chili                        11
# Moroccan Chickpea & Carrot             9
# Cassoulet                              9
# New Vegan Clam Chowder                 8
# Pozole                                 8
# Harira                                 8
# Creamy Cauliflower                     7
# Aloo Palak                             7
# Elote Corn                             6
# Sweet Potato Bisque                    6
# Potato Leek                            6
# Pasta Fagioli                          6
# Butternut Squash Moroccan Chili        6
# Sopa de Fideo                          4
# Roasted Cauliflower & Sweet Potato     3
# Tom Yum                                3
# Vegan Chicken Noodle                   3
# ...

# %%
# Export df_menu as excel
#df_menu.to_excel('farmworks_menu.xlsx', index=False)
